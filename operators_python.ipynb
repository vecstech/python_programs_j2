# %% [markdown]
# # operators in python
#
# ## 6 types of operators in python
# 1. arithematic operators
# 2. assignment operators
# 3. comparision operators
# 4. logical operators
# 5. membership operators
# 6. identity operators

# %%
# arithematic operators - +,-,*,/,//,%
a=10
b=20
c=20
d=30
print(a+b)
print(b-c)
print(b*d)
print(d/a)
print(d//a)
print(d%a)
# Out:
# 30
# 0
# 600
# 3.0
# 3
# 0

# %%
#assignmnt operators - +=,-=,*=,/=,//=,%=
a=100
a+=50
print(a)
# Out:
# 150

# %%
b=200
b-=400
print(b)
# Out:
# -200

# %%
c=50
c*=100
print(c)

# %%
# comparision operators - >,<,>=,<=,==,!=
a=10
b=20
c=20
d=30
print(a>b)
print(b==c)
print(b<c)
print(b!=c)
print(b>=a)
print(b<=a)

# %%
#logical operator - and,or, not
"""
and - both conditions are True then Results is True , rest case it False
or - either one condtion is True the result is True, rest case result is False
and truth Table
T T = T
T F = F
F T = F
F F = F
or truth table
T T = T
T F = T
F T = T
F F = F
"""
a=10
b=20
c=20
d=30
print(a>b and b==c)
print(a<b and c==b)
print(a>b or b==c)
print(not a>b and b==c)
# Out:
# False
# True
# True
# True

# %%
# membership operator - in, not in
# validating members are presnt in that sequence or group
names=["vikas","shivaji","sidh","chndra"]
print("vikas" in names)
print("shivaji" not in names)
print("Vikas" not in names)
print("vikram" in names)

# %%
# identity operators - is, is not
a=10000
b=10000
print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 2523034082288
# 2523034077264

# %%
a=10
b=10
print(a is b)
print(id(a))
print(id(b))louj
