# %% [markdown]
# # Variables in Python
# 1. variable is memory allocation to a value
# 2. examples are `name="shivaji" ` `age=26`

# %%
name="shivaji"
age=26
salary=10000.65
print(name)
print(age)
print(salary)
# Out:
# shivaji
# 26
# 10000.65

# %% [markdown]
# # key points to define variables
# 1. variables does not start with digit
# 2. variables does not allowed special characters
# 3. do not use keywords as a variables

# %%
1name="shivaji"
print(1name)

# %%
first@name="shivaji"
print(first@name)

# %%
first_name="vikas"
print(first_name)

# %%
for = "shivaji"
print(for)

# %%
for1="shivaji"
print(for1)
